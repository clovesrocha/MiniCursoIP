# %% [markdown]
# <a href="https://colab.research.google.com/github/clovesrocha/MiniCursoIP/blob/master/aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# INSTITUIÇÃO: UNINASSAU GRAÇAS
# DISCIPLINA: DESENVOLVIMENTO DE APLICAÇÕES PARA INTERNET
# DOCENTE: CLOVES ROCHA
# ESTUDANTE: ...

print('Olá, estudantes da Uninassau!')
# Out:
# Olá, estudantes da Uninassau!
